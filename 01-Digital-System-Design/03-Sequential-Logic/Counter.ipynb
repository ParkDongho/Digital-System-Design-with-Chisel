// %% [markdown]
// # Digital System Design with Chisel
//
// ### Counter

// %% [markdown]
// # Loading The Chisel Library Into a Notebook

// %%
val path = System.getProperty("user.dir") + "/../../resource/chisel_deps.sc"
interp.load.module(ammonite.ops.Path(java.nio.file.FileSystems.getDefault().getPath(path)))
// Out:
// path: String = "/home/parkdongho/dev/Digital-System-Design-with-Chisel/01-Digital-System-Design/03-Sequential-Logic/../../resource/chisel_deps.sc"

// %%
import chisel3._
import chisel3.stage._
import chisel3.util._
// Out:
// import chisel3._
//
// import chisel3.stage._
//
// import chisel3.util._

// %% [markdown]
// # ALU

// %%
class ALU[A <: Bits with Num[A]](gen: A, functions: (A, A) => A*) extends RawModule {
  val a, b = IO(Input(gen))
  val opcode = IO(Input(UInt(math.pow(2,functions.size).toInt.W)))
  val c = IO(Output(gen))
    
  private def AddSub[T <: UInt](sel: Bool, a: T, b: T){
    val c = Wire(T)
    c := a + Mux(sel, b, ~(b)) + sel
  }
  
  // filter
  private val addCases = functions.zipWithIndex.map { case (f(ai, bi), i) => (i.U, bi) }
    
  // mux
  private val foo = AddSub(selAdd, a, addCase)

  dontTouch(foo)

  c := foo
}

class MyALU extends ALU[UInt](UInt(8.W), _ + _ , _ - _, _ + _ , _ - _)
// Out:
// cmd87.sc:7: not found: value T
//     val c = Wire(T)
//                  ^cmd87.sc:12: not found: value f
//   private val addCases = functions.zipWithIndex.map { case (f(ai, bi), i) => (i.U, bi) }
//                                                             ^cmd87.sc:15: not found: value selAdd
//   private val foo = AddSub(selAdd, a, addCase)
//                            ^cmd87.sc:15: not found: value addCase
//   private val foo = AddSub(selAdd, a, addCase)
//                                       ^Compilation Failed
// Compilation Failed

// %%
math.pow(2, 3)

// %% [markdown]
// # Counter (Chisel3-Util)

// %%
class Counter private (r: Range, oldN: Option[Int] = None) extends AffectsChiselPrefix {
  require(r.length > 0, s"Counter range cannot be empty, got: $r")
  require(r.start >= 0 && r.end >= 0, s"Counter range must be positive, got: $r")

  //lazy val
  private lazy val delta = math.abs(r.step)
  private lazy val width = math.max(log2Up(r.last + 1), log2Up(r.head + 1))
  

  /** Number of counts before the counter resets
    *
    * @note Only defined for ranges starting at zero with steps of size 1. Use [[range]] for other
    * use cases.
    */
  def n: Int = oldN match {
    case Some(x) => x
    case None    =>
      // Reasonable for typical ranges
      require(
        r.start == 0 && r.step == 1,
        s"Counter.n only defined on ranges starting at 0 with step == 1, got $r. " +
          "Use underlying range."
      )
      r.last + 1
  }

  /** Creates a counter with the specified number of steps.
    *
    * @param n number of steps before the counter resets
    */
  def this(n: Int) { this(0 until math.max(1, n), Some(n)) }

  /** The current value of the counter. */
  val value = if (r.length > 1) RegInit(r.head.U(width.W)) else WireInit(r.head.U)

  /** The range of the counter values. */
  def range: Range = r

  /** Increments the counter by a step.
    *
    * @note The incremented value is registered and will be visible on the next clock cycle
    * @return whether the counter will wrap on the next clock cycle
    */
  def inc(): Bool = {
    if (r.length > 1) {
      val wrap = value === r.last.U

      if (r.step > 0) {
        // Increasing range
        value := value + delta.U
      } else {
        // Decreasing range
        value := value - delta.U
      }

      // We only need to explicitly wrap counters that don't start at zero, or
      // end on a power of two. Otherwise we just let the counter overflow
      // naturally to avoid wasting an extra mux.
      if (!(r.head == 0 && isPow2(r.last + delta))) {
        when(wrap) { value := r.head.U }
      }

      wrap
    } else {
      true.B
    }
  }

  /** Resets the counter to its initial value */
  def reset(): Unit = {
    value := r.head.U
  }
  
}
// Out:
// cmd87.sc:1: not found: type AffectsChiselPrefix
// class Counter private (r: Range, oldN: Option[Int] = None) extends AffectsChiselPrefix {
//                                                                    ^Compilation Failed
// Compilation Failed

// %%
log2Up(31)

// %% [markdown]
// # Counter (MyCounter)

// %%
class MyCounter(max: Int, min: Int = 0, initial: Int = 0) {

  val width : Int = log2Up(max + 1)

  val en    = Wire(Bool())
  val value = RegInit(initial.S(width.W))
    
  val next   = Wire(SInt(width.W))
  val sum    = Wire(SInt((width+1).W))
  val carryIn = Wire(Bool())
  val carryOut = Wire(Bool())
  
  carryOut := sum(width)

  val one = WireDefault(1.S)
  val zero = WireDefault(0.S)
  val maxValue = WireDefault(max.S)
  val minValue = WireDefault(min.S)

  carryIn := false.B
  next := one
  en := false.B
    
  sum := value + Mux(carryIn, ~next, next)
  when (en){
    value := sum
  }

  // Control
  def inc(): Unit =  {
    next := one
    carryIn := false.B
  }
  
  def inc(stride: Int): Unit =  {
    next := stride.S
    carryIn := false.B
  }

  def dec(): Unit =  {
    next := one
    carryIn := true.B
  }
    
  def dec(stride: Int): Unit =  {
    next := stride.S
    carryIn := true.B
  }
    
  def clear(): Unit = {
    next := zero
  }
  
  // Status
  def isMax(): Bool = {
    val out = Wire(Bool())
    out := value === maxValue
    out
  }
    
//  def isAlmostMax(): Bool = {
//    
//  }
    
  def isMin(): Bool = {
    val out = Wire(Bool())
    out := value === minValue
    out
  }
  
//  def isAlmostMin(): Bool = {
//    
//  }
  
  def isZero(): Bool = {
    val out = Wire(Bool())
    out := value === zero
    out
  }
    
//  def isAlmostZero(): Bool = {
//    
//  }
}
// Out:
// defined class MyCounter

// %% [markdown]
// # Counter

// %%
class helloworld(width: Int) extends Module{
  val io = IO(new Bundle{
    val en = Input(Bool())
    val opcode = Input(UInt(2.W))
    val out = Output(SInt(8.W))
  })
  
  val counter = new MyCounter(7)
  counter.en := io.en
    
  when(counter.isZero){
    counter.inc()
  }

  when(io.opcode === 1.U){
    counter.dec()
  }
    
  when(io.opcode === 2.U){
    counter.dec(2)
  }
    
  when(io.opcode === 3.U){
    counter.inc(2)
  }
  
  io.out := counter.value

}


visualize(() => new helloworld(8))
println(getVerilog(new helloworld(8)))
// Out:
// <div width="100%" height="100%" overflow="scroll"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <?xml-stylesheet href="styles.css" type="text/css"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 2.40.1 (0)
//  -->
// <!-- Title: helloworld Pages: 1 -->
// <svg width="2730pt" height="347pt"
//  viewBox="0.00 0.00 2730.00 347.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 343)">
// <title>helloworld</title>
// <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-343 2726,-343 2726,4 -4,4"/>
// <g id="clust1" class="cluster">
// <title>cluster_helloworld</title>
// <polygon fill="#fff8dc" stroke="#000000" points="8,-8 8,-331 2714,-331 2714,-8 8,-8"/>
// <text text-anchor="middle" x="1361" y="-315.8" font-family="Times,serif" font-size="14.00" fill="#000000">helloworld</text>
// </g>
// <!-- cluster_helloworld_clock -->
// <g id="node1" class="node">
// <title>cluster_helloworld_clock</title>
// <polygon fill="#cccccc" stroke="#000000" points="87.5,-259 32.5,-259 32.5,-223 87.5,-223 87.5,-259"/>
// <text text-anchor="middle" x="60" y="-237.3" font-family="Times,serif" font-size="14.00" fill="#000000">clock</text>
// </g>
// <!-- cluster_helloworld_reset -->
// <g id="node2" class="node">
// <title>cluster_helloworld_reset</title>
// <polygon fill="#cccccc" stroke="#000000" points="870.5,-156 816.5,-156 816.5,-120 870.5,-120 870.5,-156"/>
// <text text-anchor="middle" x="843.5" y="-134.3" font-family="Times,serif" font-size="14.00" fill="#000000">reset</text>
// </g>
// <!-- mux_1170687282 -->
// <g id="node36" class="node">
// <title>mux_1170687282</title>
// <polygon fill="#afeeee" stroke="transparent" points="943,-113 943,-163 1015,-163 1015,-113 943,-113"/>
// <polygon fill="none" stroke="#000000" points="943,-138 943,-163 966,-163 966,-138 943,-138"/>
// <text text-anchor="start" x="949.5" y="-146.8" font-family="Times,serif" font-size="14.00" fill="#000000">0</text>
// <polygon fill="none" stroke="#000000" points="966,-113 966,-163 992,-163 992,-113 966,-113"/>
// <text text-anchor="start" x="971" y="-134.3" font-family="Times,serif" font-size="14.00" fill="#000000">a?</text>
// <polygon fill="none" stroke="#000000" points="992,-113 992,-163 1015,-163 1015,-113 992,-113"/>
// <text text-anchor="start" x="997" y="-134.3" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// <polygon fill="none" stroke="#000000" points="943,-113 943,-138 966,-138 966,-113 943,-113"/>
// <text text-anchor="start" x="948" y="-121.8" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// </g>
// <!-- cluster_helloworld_reset&#45;&gt;mux_1170687282 -->
// <g id="edge26" class="edge">
// <title>cluster_helloworld_reset&#45;&gt;mux_1170687282:select</title>
// <path fill="none" stroke="#000000" d="M870.5948,-122.2049C906.5845,-102.5747 966.8629,-74.8881 977.4036,-102.9868"/>
// <polygon fill="#000000" stroke="#000000" points="973.9692,-103.6758 979,-113 980.8819,-102.5737 973.9692,-103.6758"/>
// </g>
// <!-- cluster_helloworld_io_en -->
// <g id="node3" class="node">
// <title>cluster_helloworld_io_en</title>
// <polygon fill="#cccccc" stroke="#000000" points="2582,-197 2528,-197 2528,-161 2582,-161 2582,-197"/>
// <text text-anchor="middle" x="2555" y="-175.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_en</text>
// </g>
// <!-- mux_1976198321 -->
// <g id="node37" class="node">
// <title>mux_1976198321</title>
// <polygon fill="#afeeee" stroke="transparent" points="2626,-142 2626,-192 2698,-192 2698,-142 2626,-142"/>
// <polygon fill="none" stroke="#000000" points="2626,-167 2626,-192 2649,-192 2649,-167 2626,-167"/>
// <text text-anchor="start" x="2631" y="-175.8" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// <polygon fill="none" stroke="#000000" points="2649,-142 2649,-192 2675,-192 2675,-142 2649,-142"/>
// <text text-anchor="start" x="2654" y="-163.3" font-family="Times,serif" font-size="14.00" fill="#000000">a?</text>
// <polygon fill="none" stroke="#000000" points="2675,-142 2675,-192 2698,-192 2698,-142 2675,-142"/>
// <text text-anchor="start" x="2680" y="-163.3" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// <polygon fill="none" stroke="#000000" points="2626,-142 2626,-167 2649,-167 2649,-142 2626,-142"/>
// <text text-anchor="start" x="2631" y="-150.8" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// </g>
// <!-- cluster_helloworld_io_en&#45;&gt;mux_1976198321 -->
// <g id="edge18" class="edge">
// <title>cluster_helloworld_io_en&#45;&gt;mux_1976198321:select</title>
// <path fill="none" stroke="#000000" d="M2582.0006,-192.6766C2609.7363,-205.4317 2650.1841,-219.99 2659.8626,-201.868"/>
// <polygon fill="#000000" stroke="#000000" points="2663.3037,-202.5143 2662,-192 2656.4624,-201.0324 2663.3037,-202.5143"/>
// </g>
// <!-- cluster_helloworld_io_opcode -->
// <g id="node4" class="node">
// <title>cluster_helloworld_io_opcode</title>
// <polygon fill="#cccccc" stroke="#000000" points="104,-165 16,-165 16,-129 104,-129 104,-165"/>
// <text text-anchor="middle" x="60" y="-143.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_opcode</text>
// </g>
// <!-- op_eq_1024 -->
// <g id="node8" class="node">
// <title>op_eq_1024</title>
// <polygon fill="#d8bfd8" stroke="transparent" points="148,-30 148,-80 231,-80 231,-30 148,-30"/>
// <polygon fill="none" stroke="#000000" points="148.5,-55 148.5,-80 171.5,-80 171.5,-55 148.5,-55"/>
// <text text-anchor="start" x="153.5" y="-63.8" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// <polygon fill="none" stroke="#000000" points="171.5,-30 171.5,-80 208.5,-80 208.5,-30 171.5,-30"/>
// <text text-anchor="start" x="176.5" y="-51.3" font-family="Times,serif" font-size="14.00" fill="#000000"> eq </text>
// <polygon fill="none" stroke="#000000" points="208.5,-30 208.5,-80 231.5,-80 231.5,-30 208.5,-30"/>
// <text text-anchor="start" x="213.5" y="-51.3" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// <polygon fill="none" stroke="#000000" points="148.5,-30 148.5,-55 171.5,-55 171.5,-30 148.5,-30"/>
// <text text-anchor="start" x="155" y="-38.8" font-family="Times,serif" font-size="14.00" fill="#000000">1</text>
// </g>
// <!-- cluster_helloworld_io_opcode&#45;&gt;op_eq_1024 -->
// <g id="edge32" class="edge">
// <title>cluster_helloworld_io_opcode&#45;&gt;op_eq_1024:in1</title>
// <path fill="none" stroke="#000000" d="M69.9065,-128.6772C82.6921,-107.5277 107.0815,-74.8782 138.5214,-68.9422"/>
// <polygon fill="#000000" stroke="#000000" points="138.8733,-72.4247 148.5,-68 138.2152,-65.4557 138.8733,-72.4247"/>
// </g>
// <!-- op_eq_1025 -->
// <g id="node11" class="node">
// <title>op_eq_1025</title>
// <polygon fill="#d8bfd8" stroke="transparent" points="283,-150 283,-200 366,-200 366,-150 283,-150"/>
// <polygon fill="none" stroke="#000000" points="283.5,-175 283.5,-200 306.5,-200 306.5,-175 283.5,-175"/>
// <text text-anchor="start" x="288.5" y="-183.8" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// <polygon fill="none" stroke="#000000" points="306.5,-150 306.5,-200 343.5,-200 343.5,-150 306.5,-150"/>
// <text text-anchor="start" x="311.5" y="-171.3" font-family="Times,serif" font-size="14.00" fill="#000000"> eq </text>
// <polygon fill="none" stroke="#000000" points="343.5,-150 343.5,-200 366.5,-200 366.5,-150 343.5,-150"/>
// <text text-anchor="start" x="348.5" y="-171.3" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// <polygon fill="none" stroke="#000000" points="283.5,-150 283.5,-175 306.5,-175 306.5,-150 283.5,-150"/>
// <text text-anchor="start" x="290" y="-158.8" font-family="Times,serif" font-size="14.00" fill="#000000">3</text>
// </g>
// <!-- cluster_helloworld_io_opcode&#45;&gt;op_eq_1025 -->
// <g id="edge42" class="edge">
// <title>cluster_helloworld_io_opcode&#45;&gt;op_eq_1025:in1</title>
// <path fill="none" stroke="#000000" d="M104.3231,-142.8746C141.3543,-140.9659 195.0114,-141.8278 239,-157 258.048,-163.5699 259.5029,-180.8183 273.5477,-186.3011"/>
// <polygon fill="#000000" stroke="#000000" points
// module helloworld(
//   input        clock,
//   input        reset,
//   input        io_en,
//   input  [1:0] io_opcode,
//   output [7:0] io_out
// );
//   reg [2:0] value;
//   wire  _T = io_opcode == 2'h1;
//   wire  _GEN_6 = io_opcode == 2'h2 | _T;
//   wire  carryIn = io_opcode == 2'h3 ? 1'h0 : _GEN_6;
//   wire [2:0] _GEN_5 = io_opcode == 2'h2 ? $signed(3'sh2) : $signed(3'sh1);
//   wire [2:0] next = io_opcode == 2'h3 ? $signed(3'sh2) : $signed(_GEN_5);
//   wire [2:0] _sum_T_1 = ~next;
//   wire [2:0] _sum_T_2 = carryIn ? $signed(_sum_T_1) : $signed(next);
//   wire [2:0] _sum_T_5 = $signed(value) + $signed(_sum_T_2);
//   wire [3:0] sum = {{1{_sum_T_5[2]}},_sum_T_5};
//   wire [3:0] _GEN_0 = io_en ? $signed(sum) : $signed({{1{value[2]}},value});
//   wire [3:0] _GEN_9 = reset ? $signed(4'sh0) : $signed(_GEN_0);
//   assign io_out = {{5{value[2]}},value};
//   always @(posedge clock) begin
//     value <= _GEN_9[2:0];
//   end
// endmodule
// defined class helloworld

// %% [markdown]
// # SRLC

// %%
import chisel3.experimental.IntParam

// Verilog Black Box
class BlackBoxSRLC(depth: Int) extends BlackBox(Map("DEPTH" -> IntParam(depth))) with HasBlackBoxInline {
  val io = IO(new Bundle{
    val clock = Input(Clock())
    val en = Input(Bool())
    val in = Input(Bool())
    val addr = Input(UInt(log2Down(depth).W))
    val out = Output(Bool())
  })
  setInline("BlackBoxSRLC.v",
    """module BlackBoxSRLC #(
      |  parameter DEPTH = 16
      |)(
      |  input   clock,
      |  output  out,
      |  input   [$clog2(DEPTH)-1:0] addr,
      |  input   in,
      |  input   en
      |);
      |  reg [DEPTH-1:0] ShiftReg;
      |  always@(posedge clock) begin
      |    if(en) begin
      |      ShiftReg <= {ShiftReg[DEPTH-2:0], in};
      |    end
      |  end
      |  assign out = ShiftReg[addr];
      |endmodule
    """.stripMargin)
}

// SRLC
class SRLC(depth: Int) extends Module{
  val io = IO(new Bundle{
    val en = Input(Bool())
    val in = Input(Bool())
    val addr = Input(UInt(log2Down(depth).W))
    val out = Output(Bool())
  })

  //val reg = Reg(UInt(depth.W))
  //val outMux = Wire(Vec(depth, Bool()))
  //  
  //when(io.en){
  //  reg := Cat(reg(depth-2, 0), io.in)
  //}
  //
  //outMux := reg.asBools
  //io.out := outMux(io.addr)
    
  val BlackBoxSRLC = Module(new BlackBoxSRLC(math.pow(2, io.addr.getWidth).toInt))
  BlackBoxSRLC.io.clock := clock
  BlackBoxSRLC.io.en := io.en
  BlackBoxSRLC.io.in := io.in
  BlackBoxSRLC.io.addr := io.addr
  io.out := BlackBoxSRLC.io.out
    
}

object SRLC{
  def apply(in: Bool, addr: UInt, en: Bool) : Bool = {
    val m = Module(new SRLC(math.pow(2, addr.getWidth).toInt))
    m.io.in := in
    m.io.addr := addr
    m.io.en := en
    m.io.out
  }
}

visualize(() => new SRLC(16))
println(getVerilog(new SRLC(16)))
// Out:
// <div width="100%" height="100%" overflow="scroll"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <?xml-stylesheet href="styles.css" type="text/css"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 2.40.1 (0)
//  -->
// <!-- Title: SRLC Pages: 1 -->
// <svg width="367pt" height="354pt"
//  viewBox="0.00 0.00 367.00 354.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 350)">
// <title>SRLC</title>
// <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-350 363,-350 363,4 -4,4"/>
// <g id="clust1" class="cluster">
// <title>cluster_SRLC</title>
// <polygon fill="#fff8dc" stroke="#000000" points="8,-8 8,-338 351,-338 351,-8 8,-8"/>
// <text text-anchor="middle" x="179.5" y="-322.8" font-family="Times,serif" font-size="14.00" fill="#000000">SRLC</text>
// </g>
// <g id="clust2" class="cluster">
// <title>cluster_SRLC_BlackBoxSRLC</title>
// <g id="a_clust2"><a xlink:href="BlackBoxSRLC.dot.svg" xlink:title="BlackBoxSRLC">
// <polygon fill="#add8e6" stroke="#000000" points="122,-16 122,-307 247,-307 247,-16 122,-16"/>
// <text text-anchor="middle" x="184.5" y="-291.8" font-family="Times,serif" font-size="14.00" fill="#000000">BlackBoxSRLC</text>
// </a>
// </g>
// </g>
// <!-- cluster_SRLC_clock -->
// <g id="node1" class="node">
// <title>cluster_SRLC_clock</title>
// <polygon fill="#cccccc" stroke="#000000" points="78.5,-307 23.5,-307 23.5,-271 78.5,-271 78.5,-307"/>
// <text text-anchor="middle" x="51" y="-285.3" font-family="Times,serif" font-size="14.00" fill="#000000">clock</text>
// </g>
// <!-- cluster_SRLC_BlackBoxSRLC_clock -->
// <g id="node7" class="node">
// <title>cluster_SRLC_BlackBoxSRLC_clock</title>
// <polygon fill="#cccccc" stroke="#000000" points="212,-276 157,-276 157,-240 212,-240 212,-276"/>
// <text text-anchor="middle" x="184.5" y="-254.3" font-family="Times,serif" font-size="14.00" fill="#000000">clock</text>
// </g>
// <!-- cluster_SRLC_clock&#45;&gt;cluster_SRLC_BlackBoxSRLC_clock -->
// <g id="edge4" class="edge">
// <title>cluster_SRLC_clock&#45;&gt;cluster_SRLC_BlackBoxSRLC_clock</title>
// <path fill="none" stroke="#000000" d="M78.6613,-282.5768C98.4407,-277.9838 125.2903,-271.7491 146.9967,-266.7086"/>
// <polygon fill="#000000" stroke="#000000" points="147.925,-270.0863 156.8741,-264.415 146.3416,-263.2677 147.925,-270.0863"/>
// </g>
// <!-- cluster_SRLC_reset -->
// <g id="node2" class="node">
// <title>cluster_SRLC_reset</title>
// <polygon fill="#cccccc" stroke="#000000" points="78,-253 24,-253 24,-217 78,-217 78,-253"/>
// <text text-anchor="middle" x="51" y="-231.3" font-family="Times,serif" font-size="14.00" fill="#000000">reset</text>
// </g>
// <!-- cluster_SRLC_io_en -->
// <g id="node3" class="node">
// <title>cluster_SRLC_io_en</title>
// <polygon fill="#cccccc" stroke="#000000" points="78,-199 24,-199 24,-163 78,-163 78,-199"/>
// <text text-anchor="middle" x="51" y="-177.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_en</text>
// </g>
// <!-- cluster_SRLC_BlackBoxSRLC_en -->
// <g id="node8" class="node">
// <title>cluster_SRLC_BlackBoxSRLC_en</title>
// <polygon fill="#cccccc" stroke="#000000" points="211.5,-222 157.5,-222 157.5,-186 211.5,-186 211.5,-222"/>
// <text text-anchor="middle" x="184.5" y="-200.3" font-family="Times,serif" font-size="14.00" fill="#000000">en</text>
// </g>
// <!-- cluster_SRLC_io_en&#45;&gt;cluster_SRLC_BlackBoxSRLC_en -->
// <g id="edge2" class="edge">
// <title>cluster_SRLC_io_en&#45;&gt;cluster_SRLC_BlackBoxSRLC_en</title>
// <path fill="none" stroke="#000000" d="M78.0157,-185.6544C97.8792,-189.0766 125.1235,-193.7703 147.0817,-197.5534"/>
// <polygon fill="#000000" stroke="#000000" points="146.6172,-201.0249 157.0663,-199.2736 147.8057,-194.1265 146.6172,-201.0249"/>
// </g>
// <!-- cluster_SRLC_io_in -->
// <g id="node4" class="node">
// <title>cluster_SRLC_io_in</title>
// <polygon fill="#cccccc" stroke="#000000" points="78,-145 24,-145 24,-109 78,-109 78,-145"/>
// <text text-anchor="middle" x="51" y="-123.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_in</text>
// </g>
// <!-- cluster_SRLC_BlackBoxSRLC_in -->
// <g id="node9" class="node">
// <title>cluster_SRLC_BlackBoxSRLC_in</title>
// <polygon fill="#cccccc" stroke="#000000" points="211.5,-168 157.5,-168 157.5,-132 211.5,-132 211.5,-168"/>
// <text text-anchor="middle" x="184.5" y="-146.3" font-family="Times,serif" font-size="14.00" fill="#000000">in</text>
// </g>
// <!-- cluster_SRLC_io_in&#45;&gt;cluster_SRLC_BlackBoxSRLC_in -->
// <g id="edge5" class="edge">
// <title>cluster_SRLC_io_in&#45;&gt;cluster_SRLC_BlackBoxSRLC_in</title>
// <path fill="none" stroke="#000000" d="M78.0157,-131.6544C97.8792,-135.0766 125.1235,-139.7703 147.0817,-143.5534"/>
// <polygon fill="#000000" stroke="#000000" points="146.6172,-147.0249 157.0663,-145.2736 147.8057,-140.1265 146.6172,-147.0249"/>
// </g>
// <!-- cluster_SRLC_io_addr -->
// <g id="node5" class="node">
// <title>cluster_SRLC_io_addr</title>
// <polygon fill="#cccccc" stroke="#000000" points="86,-91 16,-91 16,-55 86,-55 86,-91"/>
// <text text-anchor="middle" x="51" y="-69.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_addr</text>
// </g>
// <!-- cluster_SRLC_BlackBoxSRLC_addr -->
// <g id="node10" class="node">
// <title>cluster_SRLC_BlackBoxSRLC_addr</title>
// <polygon fill="#cccccc" stroke="#000000" points="211.5,-114 157.5,-114 157.5,-78 211.5,-78 211.5,-114"/>
// <text text-anchor="middle" x="184.5" y="-92.3" font-family="Times,serif" font-size="14.00" fill="#000000">addr</text>
// </g>
// <!-- cluster_SRLC_io_addr&#45;&gt;cluster_SRLC_BlackBoxSRLC_addr -->
// <g id="edge1" class="edge">
// <title>cluster_SRLC_io_addr&#45;&gt;cluster_SRLC_BlackBoxSRLC_addr</title>
// <path fill="none" stroke="#000000" d="M86.0756,-79.043C104.935,-82.2922 128.1861,-86.298 147.3533,-89.6002"/>
// <polygon fill="#000000" stroke="#000000" points="146.7937,-93.0553 157.2428,-91.304 147.9822,-86.1569 146.7937,-93.0553"/>
// </g>
// <!-- cluster_SRLC_io_out -->
// <g id="node6" class="node">
// <title>cluster_SRLC_io_out</title>
// <polygon fill="#e0ffff" stroke="#000000" points="343,-60 283,-60 283,-24 343,-24 343,-60"/>
// <text text-anchor="middle" x="313" y="-38.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_out</text>
// </g>
// <!-- cluster_SRLC_BlackBoxSRLC_out -->
// <g id="node11" class="node">
// <title>cluster_SRLC_BlackBoxSRLC_out</title>
// <polygon fill="#e0ffff" stroke="#000000" points="211.5,-60 157.5,-60 157.5,-24 211.5,-24 211.5,-60"/>
// <text text-anchor="middle" x="184.5" y="-38.3" font-family="Times,serif" font-size="14.00" fill="#000000">out</text>
// </g>
// <!-- cluster_SRLC_BlackBoxSRLC_out&#45;&gt;cluster_SRLC_io_out -->
// <g id="edge3" class="edge">
// <title>cluster_SRLC_BlackBoxSRLC_out&#45;&gt;cluster_SRLC_io_out</title>
// <path fill="none" stroke="#000000" d="M211.7515,-42C229.362,-42 252.5979,-42 272.368,-42"/>
// <polygon fill="#000000" stroke="#000000" points="272.6389,-45.5001 282.6389,-42 272.6388,-38.5001 272.6389,-45.5001"/>
// </g>
// </g>
// </svg>
// </div>
// module SRLC(
//   input        clock,
//   input        reset,
//   input        io_en,
//   input        io_in,
//   input  [3:0] io_addr,
//   output       io_out
// );
//   wire  BlackBoxSRLC_clock;
//   wire  BlackBoxSRLC_en;
//   wire  BlackBoxSRLC_in;
//   wire [3:0] BlackBoxSRLC_addr;
//   wire  BlackBoxSRLC_out;
//   BlackBoxSRLC #(.DEPTH(16)) BlackBoxSRLC (
//     .clock(BlackBoxSRLC_clock),
//     .en(BlackBoxSRLC_en),
//     .in(BlackBoxSRLC_in),
//     .addr(BlackBoxSRLC_addr),
//     .out(BlackBoxSRLC_out)
//   );
//   assign io_out = BlackBoxSRLC_out;
//   assign BlackBoxSRLC_clock = clock;
//   assign BlackBoxSRLC_en = io_en;
//   assign BlackBoxSRLC_in = io_in;
//   assign BlackBoxSRLC_addr = io_addr;
// endmodule
// import chisel3.experimental.IntParam
//
// // Verilog Black Box
//
// defined class BlackBoxSRLC
// defined class SRLC
// defined object SRLC

// %% [markdown]
// # ShiftMem

// %%
class ShiftMem[T <: chisel3.Data](gen: T, depth: Int) extends Module{
  val io = IO(new Bundle{
    val en = Input(Bool())
    val in = Input(gen)
    val addr = Input(UInt(log2Down(depth).W))
    val out = Output(gen)
  })

  private val width   : Int = gen.getWidth

  private val inData  : UInt = io.in.asUInt
  private val outData : Vec[Bool] = Wire(Vec(width, Bool()))

  for (idx <- 0 until width){
    outData(idx) := SRLC(inData(idx), io.addr, io.en)
  }
  
  io.out := outData.asTypeOf(gen)

}

object ShiftMem{
  def apply[T <: chisel3.Data](in: T, addr: UInt, en: Bool): T = {
    val shiftMem = Module(new ShiftMem(in.cloneType, math.pow(2, addr.getWidth).toInt))
    shiftMem.io.en := en
    shiftMem.io.addr := addr
    shiftMem.io.in := in
    (shiftMem.io.out)
  }
}

class helloworld[T <: chisel3.Data](gen: T, depth: Int) extends Module{
  val io = IO(new Bundle{
    val en = Input(Bool())
    val in = Input(gen)
    val addr = Input(UInt(log2Down(depth).W))
    val out = Output(gen)
  })

  //val shiftMem = Module(new ShiftMem(UInt(8.W), math.pow(2, io.addr.getWidth).toInt))
  //shiftMem.io <> io
  io.out := ShiftMem(io.in, io.addr, io.en)
}

visualize(() => new helloworld(UInt(8.W), 32))
println(getVerilog(new helloworld(UInt(8.W), 32)))
//visualize(() => new ShiftMem(UInt(8.W), 32))
// Out:
// <div width="100%" height="100%" overflow="scroll"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <?xml-stylesheet href="styles.css" type="text/css"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 2.40.1 (0)
//  -->
// <!-- Title: helloworld Pages: 1 -->
// <svg width="378pt" height="354pt"
//  viewBox="0.00 0.00 378.00 354.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 350)">
// <title>helloworld</title>
// <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-350 374,-350 374,4 -4,4"/>
// <g id="clust1" class="cluster">
// <title>cluster_helloworld</title>
// <polygon fill="#fff8dc" stroke="#000000" points="8,-8 8,-338 362,-338 362,-8 8,-8"/>
// <text text-anchor="middle" x="185" y="-322.8" font-family="Times,serif" font-size="14.00" fill="#000000">helloworld</text>
// </g>
// <g id="clust2" class="cluster">
// <title>cluster_helloworld_io_out_shiftMem</title>
// <g id="a_clust2"><a xlink:href="ShiftMem.dot.svg" xlink:title="io_out_shiftMem">
// <polygon fill="#add8e6" stroke="#000000" points="122,-16 122,-307 258,-307 258,-16 122,-16"/>
// <text text-anchor="middle" x="190" y="-291.8" font-family="Times,serif" font-size="14.00" fill="#000000">io_out_shiftMem</text>
// </a>
// </g>
// </g>
// <!-- cluster_helloworld_clock -->
// <g id="node1" class="node">
// <title>cluster_helloworld_clock</title>
// <polygon fill="#cccccc" stroke="#000000" points="78.5,-307 23.5,-307 23.5,-271 78.5,-271 78.5,-307"/>
// <text text-anchor="middle" x="51" y="-285.3" font-family="Times,serif" font-size="14.00" fill="#000000">clock</text>
// </g>
// <!-- cluster_helloworld_io_out_shiftMem_clock -->
// <g id="node7" class="node">
// <title>cluster_helloworld_io_out_shiftMem_clock</title>
// <polygon fill="#cccccc" stroke="#000000" points="217.5,-276 162.5,-276 162.5,-240 217.5,-240 217.5,-276"/>
// <text text-anchor="middle" x="190" y="-254.3" font-family="Times,serif" font-size="14.00" fill="#000000">clock</text>
// </g>
// <!-- cluster_helloworld_clock&#45;&gt;cluster_helloworld_io_out_shiftMem_clock -->
// <g id="edge2" class="edge">
// <title>cluster_helloworld_clock&#45;&gt;cluster_helloworld_io_out_shiftMem_clock</title>
// <path fill="none" stroke="#000000" d="M78.7946,-282.8012C99.9127,-278.0914 129.1831,-271.5635 152.3935,-266.3871"/>
// <polygon fill="#000000" stroke="#000000" points="153.2552,-269.781 162.2535,-264.1881 151.7314,-262.9488 153.2552,-269.781"/>
// </g>
// <!-- cluster_helloworld_reset -->
// <g id="node2" class="node">
// <title>cluster_helloworld_reset</title>
// <polygon fill="#cccccc" stroke="#000000" points="78,-253 24,-253 24,-217 78,-217 78,-253"/>
// <text text-anchor="middle" x="51" y="-231.3" font-family="Times,serif" font-size="14.00" fill="#000000">reset</text>
// </g>
// <!-- cluster_helloworld_io_en -->
// <g id="node3" class="node">
// <title>cluster_helloworld_io_en</title>
// <polygon fill="#cccccc" stroke="#000000" points="78,-199 24,-199 24,-163 78,-163 78,-199"/>
// <text text-anchor="middle" x="51" y="-177.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_en</text>
// </g>
// <!-- cluster_helloworld_io_out_shiftMem_io_en -->
// <g id="node8" class="node">
// <title>cluster_helloworld_io_out_shiftMem_io_en</title>
// <polygon fill="#cccccc" stroke="#000000" points="217,-222 163,-222 163,-186 217,-186 217,-222"/>
// <text text-anchor="middle" x="190" y="-200.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_en</text>
// </g>
// <!-- cluster_helloworld_io_en&#45;&gt;cluster_helloworld_io_out_shiftMem_io_en -->
// <g id="edge5" class="edge">
// <title>cluster_helloworld_io_en&#45;&gt;cluster_helloworld_io_out_shiftMem_io_en</title>
// <path fill="none" stroke="#000000" d="M78.1306,-185.4892C99.4655,-189.0195 129.4144,-193.9751 152.9562,-197.8704"/>
// <polygon fill="#000000" stroke="#000000" points="152.5006,-201.3426 162.9379,-199.5221 153.6434,-194.4365 152.5006,-201.3426"/>
// </g>
// <!-- cluster_helloworld_io_in -->
// <g id="node4" class="node">
// <title>cluster_helloworld_io_in</title>
// <polygon fill="#cccccc" stroke="#000000" points="78,-145 24,-145 24,-109 78,-109 78,-145"/>
// <text text-anchor="middle" x="51" y="-123.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_in</text>
// </g>
// <!-- cluster_helloworld_io_out_shiftMem_io_in -->
// <g id="node9" class="node">
// <title>cluster_helloworld_io_out_shiftMem_io_in</title>
// <polygon fill="#cccccc" stroke="#000000" points="217,-168 163,-168 163,-132 217,-132 217,-168"/>
// <text text-anchor="middle" x="190" y="-146.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_in</text>
// </g>
// <!-- cluster_helloworld_io_in&#45;&gt;cluster_helloworld_io_out_shiftMem_io_in -->
// <g id="edge3" class="edge">
// <title>cluster_helloworld_io_in&#45;&gt;cluster_helloworld_io_out_shiftMem_io_in</title>
// <path fill="none" stroke="#000000" d="M78.1306,-131.4892C99.4655,-135.0195 129.4144,-139.9751 152.9562,-143.8704"/>
// <polygon fill="#000000" stroke="#000000" points="152.5006,-147.3426 162.9379,-145.5221 153.6434,-140.4365 152.5006,-147.3426"/>
// </g>
// <!-- cluster_helloworld_io_addr -->
// <g id="node5" class="node">
// <title>cluster_helloworld_io_addr</title>
// <polygon fill="#cccccc" stroke="#000000" points="86,-91 16,-91 16,-55 86,-55 86,-91"/>
// <text text-anchor="middle" x="51" y="-69.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_addr</text>
// </g>
// <!-- cluster_helloworld_io_out_shiftMem_io_addr -->
// <g id="node10" class="node">
// <title>cluster_helloworld_io_out_shiftMem_io_addr</title>
// <polygon fill="#cccccc" stroke="#000000" points="225,-114 155,-114 155,-78 225,-78 225,-114"/>
// <text text-anchor="middle" x="190" y="-92.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_addr</text>
// </g>
// <!-- cluster_helloworld_io_addr&#45;&gt;cluster_helloworld_io_out_shiftMem_io_addr -->
// <g id="edge4" class="edge">
// <title>cluster_helloworld_io_addr&#45;&gt;cluster_helloworld_io_out_shiftMem_io_addr</title>
// <path fill="none" stroke="#000000" d="M86.0756,-78.8039C103.9368,-81.7593 125.8563,-85.3863 144.9529,-88.5462"/>
// <polygon fill="#000000" stroke="#000000" points="144.4984,-92.0185 154.9357,-90.198 145.6412,-85.1124 144.4984,-92.0185"/>
// </g>
// <!-- cluster_helloworld_io_out -->
// <g id="node6" class="node">
// <title>cluster_helloworld_io_out</title>
// <polygon fill="#e0ffff" stroke="#000000" points="354,-60 294,-60 294,-24 354,-24 354,-60"/>
// <text text-anchor="middle" x="324" y="-38.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_out</text>
// </g>
// <!-- cluster_helloworld_io_out_shiftMem_io_out -->
// <g id="node11" class="node">
// <title>cluster_helloworld_io_out_shiftMem_io_out</title>
// <polygon fill="#e0ffff" stroke="#000000" points="220,-60 160,-60 160,-24 220,-24 220,-60"/>
// <text text-anchor="middle" x="190" y="-38.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_out</text>
// </g>
// <!-- cluster_helloworld_io_out_shiftMem_io_out&#45;&gt;cluster_helloworld_io_out -->
// <g id="edge1" class="edge">
// <title>cluster_helloworld_io_out_shiftMem_io_out&#45;&gt;cluster_helloworld_io_out</title>
// <path fill="none" stroke="#000000" d="M220.0722,-42C238.7337,-42 262.9535,-42 283.3171,-42"/>
// <polygon fill="#000000" stroke="#000000" points="283.5646,-45.5001 293.5645,-42 283.5645,-38.5001 283.5646,-45.5001"/>
// </g>
// </g>
// </svg>
// </div>
// module SRLC(
//   input        clock,
//   input        io_en,
//   input        io_in,
//   input  [4:0] io_addr,
//   output       io_out
// );
//   wire  BlackBoxSRLC_clock;
//   wire  BlackBoxSRLC_en;
//   wire  BlackBoxSRLC_in;
//   wire [4:0] BlackBoxSRLC_addr;
//   wire  BlackBoxSRLC_out;
//   BlackBoxSRLC #(.DEPTH(32)) BlackBoxSRLC (
//     .clock(BlackBoxSRLC_clock),
//     .en(BlackBoxSRLC_en),
//     .in(BlackBoxSRLC_in),
//     .addr(BlackBoxSRLC_addr),
//     .out(BlackBoxSRLC_out)
//   );
//   assign io_out = BlackBoxSRLC_out;
//   assign BlackBoxSRLC_clock = clock;
//   assign BlackBoxSRLC_en = io_en;
//   assign BlackBoxSRLC_in = io_in;
//   assign BlackBoxSRLC_addr = io_addr;
// endmodule
// module ShiftMem(
//   input        clock,
//   input        io_en,
//   input  [7:0] io_in,
//   input  [4:0] io_addr,
//   output [7:0] io_out
// );
//   wire  outData_0_m_clock;
//   wire  outData_0_m_io_en;
//   wire  outData_0_m_io_in;
//   wire [4:0] outData_0_m_io_addr;
//   wire  outData_0_m_io_out;
//   wire  outData_1_m_clock;
//   wire  outData_1_m_io_en;
//   wire  outData_1_m_io_in;
//   wire [4:0] outData_1_m_io_addr;
//   wire  outData_1_m_io_out;
//   wire  outData_2_m_clock;
//   wire  outData_2_m_io_en;
//   wire  outData_2_m_io_in;
//   wire [4:0] outData_2_m_io_addr;
//   wire  outData_2_m_io_out;
//   wire  outData_3_m_clock;
//   wire  outData_3_m_io_en;
//   wire  outData_3_m_io_in;
//   wire [4:0] outData_3_m_io_addr;
//   wire  outData_3_m_io_out;
//   wire  outData_4_m_clock;
//   wire  outData_4_m_io_en;
//   wire  outData_4_m_io_in;
//   wire [4:0] outData_4_m_io_addr;
//   wire  outData_4_m_io_out;
//   wire  outData_5_m_clock;
//   wire  outData_5_m_io_en;
//   wire  outData_5_m_io_in;
//   wire [4:0] outData_5_m_io_addr;
//   wire  outData_5_m_io_out;
//   wire  outData_6_m_clock;
//   wire  outData_6_m_io_en;
//   wire  outData_6_m_io_in;
//   wire [4:0] outData_6_m_io_addr;
//   wire  outData_6_m_io_out;
//   wire  outData_7_m_clock;
//   wire  outData_7_m_io_en;
//   wire  outData_7_m_io_in;
//   wire [4:0] outData_7_m_io_addr;
//   wire  outData_7_m_io_out;
//   wire  outData_1 = outData_1_m_io_out;
//   wire  outData_0 = outData_0_m_io_out;
//   wire  outData_3 = outData_3_m_io_out;
//   wire  outData_2 = outData_2_m_io_out;
//   wire [3:0] io_out_lo = {outData_3,outData_2,outData_1,outData_0};
//   wire  outData_5 = outData_5_m_io_out;
//   wire  outData_4 = outData_4_m_io_out;
//   wire  outData_7 = outData_7_m_io_out;
//   wire  outData_6 = outData_6_m_io_out;
//   wire [3:0] io_out_hi = {outData_7,outData_6,outData_5,outData_4};
//   SRLC outData_0_m (
//     .clock(outData_0_m_clock),
//     .io_en(outData_0_m_io_en),
//     .io_in(outData_0_m_io_in),
//     .io_addr(outData_0_m_io_addr),
//     .io_out(outData_0_m_io_out)
//   );
//   SRLC outData_1_m (
//     .clock(outData_1_m_clock),
//     .io_en(outData_1_m_io_en),
//     .io_in(outData_1_m_io_in),
//     .io_addr(outData_1_m_io_addr),
//     .io_out(outData_1_m_io_out)
//   );
//   SRLC outData_2_m (
//     .clock(outData_2_m_clock),
//     .io_en(outData_2_m_io_en),
//     .io_in(outData_2_m_io_in),
//     .io_addr(outData_2_m_io_addr),
//     .io_out(outData_2_m_io_out)
//   );
//   SRLC outData_3_m (
//     .clock(outData_3_m_clock),
//     .io_en(outData_3_m_io_en),
//     .io_in(outData_3_m_io_in),
//     .io_addr(outData_3_m_io_addr),
//     .io_out(outData_3_m_io_out)
//   );
//   SRLC outData_4_m (
//     .clock(outData_4_m_clock),
//     .io_en(outData_4_m_io_en),
//     .io_in(outData_4_m_io_in),
//     .io_addr(outData_4_m_io_addr),
//     .io_out(outData_4_m_io_out)
//   );
//   SRLC outData_5_m (
//     .clock(outData_5_m_clock),
//     .io_en(outData_5_m_io_en),
//     .io_in(outData_5_m_io_in),
//     .io_addr(outData_5_m_io_addr),
//     .io_out(outData_5_m_io_out)
//   );
//   SRLC outData_6_m (
//     .clock(outData_6_m_clock),
//     .io_en(outData_6_m_io_en),
//     .io_in(outData_6_m_io_in),
//     .io_addr(outData_6_m_io_addr),
//     .io_out(outData_6_m_io_out)
//   );
//   SRLC outData_7_m (
//     .clock(outData_7_m_clock),
//     .io_en(outData_7_m_io_en),
//     .io_in(outData_7_m_io_in),
//     .io_addr(outData_7_m_io_addr),
//     .io_out(outData_7_m_io_out)
//   );
//   assign io_out = {io_out_hi,io_out_lo};
//   assign outData_0_m_clock = clock;
//   assign outData_0_m_io_en = io_en;
//   assign outData_0_m_io_in = io_in[0];
//   assign outData_0_m_io_addr = io_addr;
//   assign outData_1_m_clock = clock;
//   assign outData_1_m_io_en = io_en;
//   assign outData_1_m_io_in = io_in[1];
//   assign outData_1_m_io_addr = io_addr;
//   assign outData_2_m_clock = clock;
//   assign outData_2_m_io_en = io_en;
//   assign outData_2_m_io_in = io_in[2];
//   assign outData_2_m_io_addr = io_addr;
//   assign outData_3_m_clock = clock;
//   assign outData_3_m_io_en = io_en;
//   assign outData_3_m_io_in = io_in[3];
//   assign outData_3_m_io_addr = io_addr;
//   assign outData_4_m_clock = clock;
//   assign outData_4_m_io_en = io_en;
//   assign outData_4_m_io_in = io_in[4];
//   assign outData_4_m_io_addr = io_addr;
//   assign outData_5_m_clock = clock;
//   assign outData_5_m_io_en = io_en;
//   assign outData_5_m_io_in = io_in[5];
//   assign outData_5_m_io_addr = io_addr;
//   assign outData_6_m_clock = clock;
//   assign outData_6_m_io_en = io_en;
//   assign outData_6_m_io_in = io_in[6];
//   assign outData_6_m_io_addr = io_addr;
//   assign outData_7_m_clock = clock;
//   assign outData_7_m_io_en = io_en;
//   assign outData_7_m_io_in = io_in[7];
//   assign outData_7_m_io_addr = io_addr;
// endmodule
// module helloworld(
//   input        clock,
//   input        reset,
//   input        io_en,
//   input  [7:0] io_in,
//   input  [4:0] io_addr,
//   output [7:0] io_out
// );
//   wire  io_out_shiftMem_clock;
//   wire  io_out_shiftMem_io_en;
//   wire [7:0] io_out_shiftMem_io_in;
//   wire [4:0] io_out_shiftMem_io_addr;
//   wire [7:0] io_out_shiftMem_io_out;
//   ShiftMem io_out_shiftMem (
//     .clock(io_out_shiftMem_clock),
//     .io_en(io_out_shiftMem_io_en),
//     .io_in(io_out_shiftMem_io_in),
//     .io_addr(io_out_shiftMem_io_addr),
//     .io_out(io_out_shiftMem_io_out)
//   );
//   assign io_out = io_out_shiftMem_io_out;
//   assign io_out_shiftMem_clock = clock;
//   assign io_out_shiftMem_io_en = io_en;
//   assign io_out_shiftMem_io_in = io_in;
//   assign io_out_shiftMem_io_addr = io_addr;
// endmodule
// defined class ShiftMem
// defined object ShiftMem
// defined class helloworld

// %% [markdown]
// # ShiftFIFO

// %%
class ShiftFIFO(depth: Int) extends Module{
  val io = IO(new Bundle{
    val enq = Flipped(DecoupledIO(UInt(8.W)))
    val deq = DecoupledIO(UInt(8.W))
  })
  
  //Module Instantiation (Counter)
  val counter = new MyCounter(depth-1) // 0 to depth-1
  //Module Instantiation (ShiftMem)
  io.deq.bits := ShiftMem(io.enq.bits, counter.value.asUInt, io.enq.fire)
  
  //Status(Counter)
  io.enq.ready :=  counter.isMax()
  io.deq.valid := ~counter.isMin()

  //Control
  when(io.enq.fire ^ io.deq.fire){
    counter.en := true.B  
    when(io.enq.fire){
      counter.inc()
    }
    when(io.deq.fire){
      counter.dec()
    }
  } .otherwise{
    counter.en := false.B
  }
}

visualize(() => new ShiftFIFO(32))
println(getVerilog(new ShiftFIFO(32)))
// Out:
// <div width="100%" height="100%" overflow="scroll"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <?xml-stylesheet href="styles.css" type="text/css"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 2.40.1 (0)
//  -->
// <!-- Title: ShiftFIFO Pages: 1 -->
// <svg width="3938pt" height="722pt"
//  viewBox="0.00 0.00 3938.00 721.74" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 717.7406)">
// <title>ShiftFIFO</title>
// <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-717.7406 3934,-717.7406 3934,4 -4,4"/>
// <g id="clust1" class="cluster">
// <title>cluster_ShiftFIFO</title>
// <polygon fill="#fff8dc" stroke="#000000" points="8,-8 8,-480 3922,-480 3922,-8 8,-8"/>
// <text text-anchor="middle" x="1965" y="-464.8" font-family="Times,serif" font-size="14.00" fill="#000000">ShiftFIFO</text>
// </g>
// <g id="clust2" class="cluster">
// <title>cluster_ShiftFIFO_io_deq_bits_shiftMem</title>
// <g id="a_clust2"><a xlink:href="ShiftMem.dot.svg" xlink:title="io_deq_bits_shiftMem">
// <polygon fill="#add8e6" stroke="#000000" points="3599,-16 3599,-307 3772,-307 3772,-16 3599,-16"/>
// <text text-anchor="middle" x="3685.5" y="-291.8" font-family="Times,serif" font-size="14.00" fill="#000000">io_deq_bits_shiftMem</text>
// </a>
// </g>
// </g>
// <!-- cluster_ShiftFIFO_clock -->
// <g id="node1" class="node">
// <title>cluster_ShiftFIFO_clock</title>
// <polygon fill="#cccccc" stroke="#000000" points="3527,-227 3472,-227 3472,-191 3527,-191 3527,-227"/>
// <text text-anchor="middle" x="3499.5" y="-205.3" font-family="Times,serif" font-size="14.00" fill="#000000">clock</text>
// </g>
// <!-- cluster_ShiftFIFO_io_deq_bits_shiftMem_clock -->
// <g id="node9" class="node">
// <title>cluster_ShiftFIFO_io_deq_bits_shiftMem_clock</title>
// <polygon fill="#cccccc" stroke="#000000" points="3712.5,-222 3657.5,-222 3657.5,-186 3712.5,-186 3712.5,-222"/>
// <text text-anchor="middle" x="3685" y="-200.3" font-family="Times,serif" font-size="14.00" fill="#000000">clock</text>
// </g>
// <!-- cluster_ShiftFIFO_clock&#45;&gt;cluster_ShiftFIFO_io_deq_bits_shiftMem_clock -->
// <g id="edge7" class="edge">
// <title>cluster_ShiftFIFO_clock&#45;&gt;cluster_ShiftFIFO_io_deq_bits_shiftMem_clock</title>
// <path fill="none" stroke="#000000" d="M3527.2712,-208.2514C3559.1919,-207.3911 3611.7477,-205.9745 3647.3356,-205.0152"/>
// <polygon fill="#000000" stroke="#000000" points="3647.4403,-208.5138 3657.3423,-204.7455 3647.2516,-201.5163 3647.4403,-208.5138"/>
// </g>
// <!-- cluster_ShiftFIFO_reset -->
// <g id="node2" class="node">
// <title>cluster_ShiftFIFO_reset</title>
// <polygon fill="#cccccc" stroke="#000000" points="2301,-256 2247,-256 2247,-220 2301,-220 2301,-256"/>
// <text text-anchor="middle" x="2274" y="-234.3" font-family="Times,serif" font-size="14.00" fill="#000000">reset</text>
// </g>
// <!-- mux_526643058 -->
// <g id="node45" class="node">
// <title>mux_526643058</title>
// <polygon fill="#afeeee" stroke="transparent" points="2362,-202 2362,-252 2434,-252 2434,-202 2362,-202"/>
// <polygon fill="none" stroke="#000000" points="2362,-227 2362,-252 2385,-252 2385,-227 2362,-227"/>
// <text text-anchor="start" x="2368.5" y="-235.8" font-family="Times,serif" font-size="14.00" fill="#000000">0</text>
// <polygon fill="none" stroke="#000000" points="2385,-202 2385,-252 2411,-252 2411,-202 2385,-202"/>
// <text text-anchor="start" x="2390" y="-223.3" font-family="Times,serif" font-size="14.00" fill="#000000">a?</text>
// <polygon fill="none" stroke="#000000" points="2411,-202 2411,-252 2434,-252 2434,-202 2411,-202"/>
// <text text-anchor="start" x="2416" y="-223.3" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// <polygon fill="none" stroke="#000000" points="2362,-202 2362,-227 2385,-227 2385,-202 2362,-202"/>
// <text text-anchor="start" x="2367" y="-210.8" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// </g>
// <!-- cluster_ShiftFIFO_reset&#45;&gt;mux_526643058 -->
// <g id="edge30" class="edge">
// <title>cluster_ShiftFIFO_reset&#45;&gt;mux_526643058:select</title>
// <path fill="none" stroke="#000000" d="M2301.2123,-246.3886C2330.2994,-254.7653 2374.4901,-265.6332 2391.2424,-259.9184"/>
// <polygon fill="#000000" stroke="#000000" points="2394.1708,-261.8787 2398,-252 2388.8462,-257.3346 2394.1708,-261.8787"/>
// </g>
// <!-- cluster_ShiftFIFO_io_enq_valid -->
// <g id="node3" class="node">
// <title>cluster_ShiftFIFO_io_enq_valid</title>
// <polygon fill="#cccccc" stroke="#000000" points="121,-226 16,-226 16,-190 121,-190 121,-226"/>
// <text text-anchor="middle" x="68.5" y="-204.3" font-family="Times,serif" font-size="14.00" fill="#000000">io_enq_valid</text>
// </g>
// <!-- op_and_1059 -->
// <g id="node16" class="node">
// <title>op_and_1059</title>
// <polygon fill="#d8bfd8" stroke="transparent" points="165,-328 165,-378 257,-378 257,-328 165,-328"/>
// <polygon fill="none" stroke="#000000" points="165,-353 165,-378 188,-378 188,-353 165,-353"/>
// <text text-anchor="start" x="170" y="-361.8" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// <polygon fill="none" stroke="#000000" points="188,-328 188,-378 234,-378 234,-328 188,-328"/>
// <text text-anchor="start" x="193" y="-349.3" font-family="Times,serif" font-size="14.00" fill="#000000"> and </text>
// <polygon fill="none" stroke="#000000" points="234,-328 234,-378 257,-378 257,-328 234,-328"/>
// <text text-anchor="start" x="239" y="-349.3" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// <polygon fill="none" stroke="#000000" points="165,-328 165,-353 188,-353 188,-328 165,-328"/>
// <text text-anchor="start" x="170" y="-336.8" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// </g>
// <!-- cluster_ShiftFIFO_io_enq_valid&#45;&gt;op_and_1059 -->
// <g id="edge37" class="edge">
// <title>cluster_ShiftFIFO_io_enq_valid&#45;&gt;op_and_1059:in2</title>
// <path fill="none" stroke="#000000" d="M101.0453,-226.1403C130.2752,-244.9007 169.469,-277.1401 175.2703,-317.7792"/>
// <polygon fill="#000000" stroke="#000000" points="171.7967,-318.2746 176,-328 178.779,-317.7761 171.7967,-318.2746"/>
// </g>
// <!-- op_and_1078 -->
// <g id="node48" class="node">
// <title>op_and_1078</title>
// <polygon fill="#d8bfd8" stroke="transparent" points="3453.5,-119 3453.5,-169 3545.5,-169 3545.5,-119 3453.5,-119"/>
// <polygon fill="none" stroke="#000000" points="3453.5,-144 3453.5,-169 3476.5,-169 3476.5,-144 3453.5,-144"/>
// <text text-anchor="start" x="3458.5" y="-152.8" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// <polygon fill="none" stroke="#000000" points="3476.5,-119 3476.5,-169 3522.5,-169 3522.5,-119 3476.5,-119"/>
// <text text-anchor="start" x="3481.5" y="-140.3" font-family="Times,serif" font-size="14.00" fill="#000000"> and </text>
// <polygon fill="none" stroke="#000000" points="3522.5,-119 3522.5,-169 3545.5,-169 3545.5,-119 3522.5,-119"/>
// <text text-anchor="start" x="3527.5" y="-140.3" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// <polygon fill="none" stroke="#000000" points="3453.5,-119 3453.5,-144 3476.5,-144 3476.5,-119 3453.5,-119"/>
// <text text-anchor="start" x="3458.5" y="-127.8" font-family="Times,serif" font-size="14.00" fill="#000000">●</text>
// </g>
// <!-- cluster_ShiftFIFO_io_enq_valid&#45;&gt;op_and_1078 -->
// <g id="edge27" class="edge">
// <title>cluster_ShiftFIFO_io_enq_valid&#45;&gt;op_and_1078:in2</title>
// <path fill="none" stroke="#000000" d="M87.9421,-189.9227C128.9395,-153.7713 228.6778,-76 328,-76 328,-76 328,-76 3193,-76 3307.8634,-76 3333.6919,-127.8246 3443.3384,-130.8611"/>
// <polygon fill="#000000" stroke="#000000" points="3443.4531,-134.3629 3453.5,-131 3443.5488,-127.3636 3443.4531,-134.3629"/>
// </g>
// <!-- cluster_ShiftFIFO_io_enq_bits -->
// <g id="node4" class="node">
// <title>cluster_ShiftFIFO_io_enq_bits</title>
// <polygon fill="#cccccc" stroke="#000000" points="3548.5,-97 3450.5,-97 3450.5,-61 3548.5,-61 3548.5,-97"/>
// <text text-anchor="middle" x="3499.5" y="-75.3" font-family="Times,serif" font-size="14.00" fill="#000000">
// module SRLC(
//   input        clock,
//   input        io_en,
//   input        io_in,
//   input  [4:0] io_addr,
//   output       io_out
// );
//   wire  BlackBoxSRLC_clock;
//   wire  BlackBoxSRLC_en;
//   wire  BlackBoxSRLC_in;
//   wire [4:0] BlackBoxSRLC_addr;
//   wire  BlackBoxSRLC_out;
//   BlackBoxSRLC #(.DEPTH(32)) BlackBoxSRLC (
//     .clock(BlackBoxSRLC_clock),
//     .en(BlackBoxSRLC_en),
//     .in(BlackBoxSRLC_in),
//     .addr(BlackBoxSRLC_addr),
//     .out(BlackBoxSRLC_out)
//   );
//   assign io_out = BlackBoxSRLC_out;
//   assign BlackBoxSRLC_clock = clock;
//   assign BlackBoxSRLC_en = io_en;
//   assign BlackBoxSRLC_in = io_in;
//   assign BlackBoxSRLC_addr = io_addr;
// endmodule
// module ShiftMem(
//   input        clock,
//   input        io_en,
//   input  [7:0] io_in,
//   input  [4:0] io_addr,
//   output [7:0] io_out
// );
//   wire  outData_0_m_clock;
//   wire  outData_0_m_io_en;
//   wire  outData_0_m_io_in;
//   wire [4:0] outData_0_m_io_addr;
//   wire  outData_0_m_io_out;
//   wire  outData_1_m_clock;
//   wire  outData_1_m_io_en;
//   wire  outData_1_m_io_in;
//   wire [4:0] outData_1_m_io_addr;
//   wire  outData_1_m_io_out;
//   wire  outData_2_m_clock;
//   wire  outData_2_m_io_en;
//   wire  outData_2_m_io_in;
//   wire [4:0] outData_2_m_io_addr;
//   wire  outData_2_m_io_out;
//   wire  outData_3_m_clock;
//   wire  outData_3_m_io_en;
//   wire  outData_3_m_io_in;
//   wire [4:0] outData_3_m_io_addr;
//   wire  outData_3_m_io_out;
//   wire  outData_4_m_clock;
//   wire  outData_4_m_io_en;
//   wire  outData_4_m_io_in;
//   wire [4:0] outData_4_m_io_addr;
//   wire  outData_4_m_io_out;
//   wire  outData_5_m_clock;
//   wire  outData_5_m_io_en;
//   wire  outData_5_m_io_in;
//   wire [4:0] outData_5_m_io_addr;
//   wire  outData_5_m_io_out;
//   wire  outData_6_m_clock;
//   wire  outData_6_m_io_en;
//   wire  outData_6_m_io_in;
//   wire [4:0] outData_6_m_io_addr;
//   wire  outData_6_m_io_out;
//   wire  outData_7_m_clock;
//   wire  outData_7_m_io_en;
//   wire  outData_7_m_io_in;
//   wire [4:0] outData_7_m_io_addr;
//   wire  outData_7_m_io_out;
//   wire  outData_1 = outData_1_m_io_out;
//   wire  outData_0 = outData_0_m_io_out;
//   wire  outData_3 = outData_3_m_io_out;
//   wire  outData_2 = outData_2_m_io_out;
//   wire [3:0] io_out_lo = {outData_3,outData_2,outData_1,outData_0};
//   wire  outData_5 = outData_5_m_io_out;
//   wire  outData_4 = outData_4_m_io_out;
//   wire  outData_7 = outData_7_m_io_out;
//   wire  outData_6 = outData_6_m_io_out;
//   wire [3:0] io_out_hi = {outData_7,outData_6,outData_5,outData_4};
//   SRLC outData_0_m (
//     .clock(outData_0_m_clock),
//     .io_en(outData_0_m_io_en),
//     .io_in(outData_0_m_io_in),
//     .io_addr(outData_0_m_io_addr),
//     .io_out(outData_0_m_io_out)
//   );
//   SRLC outData_1_m (
//     .clock(outData_1_m_clock),
//     .io_en(outData_1_m_io_en),
//     .io_in(outData_1_m_io_in),
//     .io_addr(outData_1_m_io_addr),
//     .io_out(outData_1_m_io_out)
//   );
//   SRLC outData_2_m (
//     .clock(outData_2_m_clock),
//     .io_en(outData_2_m_io_en),
//     .io_in(outData_2_m_io_in),
//     .io_addr(outData_2_m_io_addr),
//     .io_out(outData_2_m_io_out)
//   );
//   SRLC outData_3_m (
//     .clock(outData_3_m_clock),
//     .io_en(outData_3_m_io_en),
//     .io_in(outData_3_m_io_in),
//     .io_addr(outData_3_m_io_addr),
//     .io_out(outData_3_m_io_out)
//   );
//   SRLC outData_4_m (
//     .clock(outData_4_m_clock),
//     .io_en(outData_4_m_io_en),
//     .io_in(outData_4_m_io_in),
//     .io_addr(outData_4_m_io_addr),
//     .io_out(outData_4_m_io_out)
//   );
//   SRLC outData_5_m (
//     .clock(outData_5_m_clock),
//     .io_en(outData_5_m_io_en),
//     .io_in(outData_5_m_io_in),
//     .io_addr(outData_5_m_io_addr),
//     .io_out(outData_5_m_io_out)
//   );
//   SRLC outData_6_m (
//     .clock(outData_6_m_clock),
//     .io_en(outData_6_m_io_en),
//     .io_in(outData_6_m_io_in),
//     .io_addr(outData_6_m_io_addr),
//     .io_out(outData_6_m_io_out)
//   );
//   SRLC outData_7_m (
//     .clock(outData_7_m_clock),
//     .io_en(outData_7_m_io_en),
//     .io_in(outData_7_m_io_in),
//     .io_addr(outData_7_m_io_addr),
//     .io_out(outData_7_m_io_out)
//   );
//   assign io_out = {io_out_hi,io_out_lo};
//   assign outData_0_m_clock = clock;
//   assign outData_0_m_io_en = io_en;
//   assign outData_0_m_io_in = io_in[0];
//   assign outData_0_m_io_addr = io_addr;
//   assign outData_1_m_clock = clock;
//   assign outData_1_m_io_en = io_en;
//   assign outData_1_m_io_in = io_in[1];
//   assign outData_1_m_io_addr = io_addr;
//   assign outData_2_m_clock = clock;
//   assign outData_2_m_io_en = io_en;
//   assign outData_2_m_io_in = io_in[2];
//   assign outData_2_m_io_addr = io_addr;
//   assign outData_3_m_clock = clock;
//   assign outData_3_m_io_en = io_en;
//   assign outData_3_m_io_in = io_in[3];
//   assign outData_3_m_io_addr = io_addr;
//   assign outData_4_m_clock = clock;
//   assign outData_4_m_io_en = io_en;
//   assign outData_4_m_io_in = io_in[4];
//   assign outData_4_m_io_addr = io_addr;
//   assign outData_5_m_clock = clock;
//   assign outData_5_m_io_en = io_en;
//   assign outData_5_m_io_in = io_in[5];
//   assign outData_5_m_io_addr = io_addr;
//   assign outData_6_m_clock = clock;
//   assign outData_6_m_io_en = io_en;
//   assign outData_6_m_io_in = io_in[6];
//   assign outData_6_m_io_addr = io_addr;
//   assign outData_7_m_clock = clock;
//   assign outData_7_m_io_en = io_en;
//   assign outData_7_m_io_in = io_in[7];
//   assign outData_7_m_io_addr = io_addr;
// endmodule
// module ShiftFIFO(
//   input        clock,
//   input        reset,
//   output       io_enq_ready,
//   input        io_enq_valid,
//   input  [7:0] io_enq_bits,
//   input        io_deq_ready,
//   output       io_deq_valid,
//   output [7:0] io_deq_bits
// );
//   wire  io_deq_bits_shiftMem_clock;
//   wire  io_deq_bits_shiftMem_io_en;
//   wire [7:0] io_deq_bits_shiftMem_io_in;
//   wire [4:0] io_deq_bits_shiftMem_io_addr;
//   wire [7:0] io_deq_bits_shiftMem_io_out;
//   reg [4:0] value;
//   wire  _T = io_enq_ready & io_enq_valid;
//   wire  _T_1 = io_deq_ready & io_deq_valid;
//   wire  en = _T ^ _T_1;
//   wire  carryIn = en & _T_1;
//   wire [4:0] _sum_T_1 = ~5'sh1;
//   wire [4:0] _sum_T_2 = carryIn ? $signed(_sum_T_1) : $signed(5'sh1);
//   wire [4:0] _sum_T_5 = $signed(value) + $signed(_sum_T_2);
//   wire [5:0] sum = {{1{_sum_T_5[4]}},_sum_T_5};
//   wire [5:0] _GEN_0 = en ? $signed(sum) : $signed({{1{value[4]}},value});
//   wire [5:0] _GEN_8 = {{1{value[4]}},value};
//   wire  io_deq_valid_out = $signed(value) == 5'sh0;
//   wire [5:0] _GEN_10 = reset ? $signed(6'sh0) : $signed(_GEN_0);
//   ShiftMem io_deq_bits_shiftMem (
//     .clock(io_deq_bits_shiftMem_clock),
//     .io_en(io_deq_bits_shiftMem_io_en),
//     .io_in(io_deq_bits_shiftMem_io_in),
//     .io_addr(io_deq_bits_shiftMem_io_addr),
//     .io_out(io_deq_bits_shiftMem_io_out)
//   );
//   assign io_enq_ready = $signed(_GEN_8) == 6'sh1f;
//   assign io_deq_valid = ~io_deq_valid_out;
//   assign io_deq_bits = io_deq_bits_shiftMem_io_out;
//   assign io_deq_bits_shiftMem_clock = clock;
//   assign io_deq_bits_shiftMem_io_en = io_enq_ready & io_enq_valid;
//   assign io_deq_bits_shiftMem_io_in = io_enq_bits;
//   assign io_deq_bits_shiftMem_io_addr = value;
//   always @(posedge clock) begin
//     value <= _GEN_10[4:0];
//   end
// endmodule
// defined class ShiftFIFO
